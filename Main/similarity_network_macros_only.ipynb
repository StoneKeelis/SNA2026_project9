# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
fineli_data = pd.read_csv("../Datasets/fineli.csv", sep=";")
fineli_data = fineli_data[["name", "energia, laskennallinen (kJ)", "rasva (g)", "hiilihydraatti imeytyvä (g)", "proteiini (g)"]]

fineli_data.head()
# Out:
#                                         name  energia, laskennallinen (kJ)  \
# 0                                      Ahven                           345
# 1               Ahven, leivitetty, paistettu                           660
# 2         Ahven, paistettu, ei korppujauhoja                           600
# 3  Ahven, paistettu voissa, ei korppujauhoja                           595
# 4                   Ahvenet foliossa, voissa                           496
#
#   rasva (g) hiilihydraatti imeytyvä (g) proteiini (g)
# 0       0.7                           0          18.8
# 1       6.5                         4.7          19.9
# 2       6.8                        <0.1          20.5
# 3       7.3                        <0.1          19.1
# 4       4.1                         0.6          19.5

# %%
CQP_1 = pd.read_csv("../Datasets/CQP1.csv", sep=";")
CQP_2 = pd.read_csv("../Datasets/CQP2.csv", sep=";")
CQP_3 = pd.read_csv("../Datasets/CQP3.csv", sep=";")
CQP_4 = pd.read_csv("../Datasets/CQP4.csv", sep=";")
CQP_5 = pd.read_csv("../Datasets/CQP5.csv", sep=";")
CQP_6 = pd.read_csv("../Datasets/CQP6.csv", sep=";")
CQP_7 = pd.read_csv("../Datasets/CQP7.csv", sep=";")
CQP_8 = pd.read_csv("../Datasets/CQP8.csv", sep=";")

CQP = pd.concat([CQP_1, CQP_2, CQP_3, CQP_4, CQP_5, CQP_6, CQP_7, CQP_8])
CQP = CQP[["word", "text_thread_id"]]

CQP.head()
# Out:
#             word text_thread_id
# 0              Σ              Σ
# 1     hapankaali       16796146
# 2        hedelmä       17969829
# 3  hampurilainen       18191211
# 4        hedelmä       17254127

# %% [markdown]
# Removing duplicates from CQP data. This list will be used as a filter for the Fineli dataframe

# %%
food_filter = CQP["word"].dropna().str.lower().drop_duplicates().tolist()
food_filter.remove('σ')

print(food_filter)
print(len(food_filter))
# Out:
# ['hapankaali', 'hedelmä', 'hampurilainen', 'ananas', 'banaani', 'ahven', 'hauki', 'hernekeitto', 'bataatti', 'chili', 'broileri', 'hillo', 'herne', 'appelsiini', 'hiiva', 'anjovis', 'avokado', 'ateriankorvike', 'etana', 'hunaja', 'hummeri', 'ahvenet', 'hoki', 'borssikeitto', 'hirssi', 'herkkusieni', 'haaparousku', 'grillimakkara', 'creme', 'basilika', 'auringonkukansiemen', 'aromisuola', 'hirvenliha', 'donitsi', 'blini', 'ankerias', 'herkkutatti', 'granaattiomena', 'graavilohi', 'fruktoosi', 'etikkakurkku', 'energiajuoma', 'elovena', 'chiansiemen', 'broilerikeitto', 'broilerifilee', 'aprikoosi', 'hummus', 'herkkusienikeitto', 'booli', 'amarantti', 'hedelmäsalaatti', 'greippi', 'hirvenpaisti', 'hillosipulisäilyke', 'herneenverso', 'heraproteiinikonsentraatti', 'herajauhe', 'hedelmäjuoma', 'hedelmähillo', 'hasselpähkinäjuoma', 'hapanlohko', 'hapankurkku', 'hapankorppu', 'hapankaalikeitto', 'hampunsiemen', 'guava', 'fenkolikeitto', 'fenkoli', 'etikkasienisäilyke', 'et
', 'lehtikaalisipsit', 'lanttupiirakka', 'lampaanliha', 'lampaankääpä', 'kyssäkaali', 'kvinoa', 'kurpitsansiemen', 'ksylitolipurukumi', 'kirjolohifilee', 'kinkkupiirakka', 'kilohaili', 'kikherne', 'kermaperuna', 'kermakastike', 'kauravelli', 'katkarapukeitto', 'katajanmarja', 'lampaanpaisti', 'kukkakaalimuhennos', 'ksylitolipastilli', 'korvasienikeitto', 'kookosvesi', 'kookosjuoma', 'kevätkääryle', 'kermalikööri', 'kauravalmiste', 'kauramakaroni', 'katkarapumuhennos', 'kasvissose', 'lindst ...
# 691

# %% [markdown]
# Defining similarity based on nutritional vectors

# %%
from sklearn.preprocessing import StandardScaler

fineli_data["name"] = fineli_data["name"].str.lower()

filtered_df = fineli_data[fineli_data["name"].isin(food_filter)].copy()

features = ["energia, laskennallinen (kJ)", "rasva (g)", "hiilihydraatti imeytyvä (g)", "proteiini (g)"]
X = filtered_df[features].copy()

for col in X.columns:
    X[col] = X[col].astype(str).str.replace("<", "", regex=False)

X = X.apply(pd.to_numeric, errors="coerce")
X = X.dropna()

filtered_df = filtered_df.loc[X.index]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Cosine similariy

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(X_scaled)

sim_df = pd.DataFrame(
    similarity_matrix,
    index=filtered_df["name"],
    columns=filtered_df["name"]
)

# %% [markdown]
# Creating edges based on similarity threshold

# %%
threshold = 0.75

edges = []

names = filtered_df["name"].tolist()

for i in range(len(names)):
    for j in range(i + 1, len(names)):
        if similarity_matrix[i, j] > threshold:
            edges.append((names[i], names[j]))

# %% [markdown]
# Creating graph for data

# %%
G = nx.Graph()
G.add_nodes_from(names)
G.add_edges_from(edges)

# %% [markdown]
# Computing number of nodes and edges, average degree, clustering coefficient, density and diameter and average path length

# %%
print(f"Nodes: {len(G.nodes)}")
print(f"Edges: {len(G.edges)}")

average_degree = sum(dict(G.degree()).values()) / len(G)

print(f"Average degree: {round(average_degree)}")

average_clustering_coefficient = nx.average_clustering(G)
print(f"Average clustering coefficient: {round(average_clustering_coefficient, 5)}")

density = nx.density(G)
largest_connected_component = max(nx.connected_components(G), key=len)
G_sub = G.subgraph(largest_connected_component)
diameter = nx.diameter(G_sub)

print(f"Density: {round(density, 4)}")
print(f"Diameter: ", diameter)

average_path_length = nx.average_shortest_path_length(G_sub)
print(f"Average shortest path length: {round(average_path_length, 2)}")
# Out:
# Nodes: 223
# Edges: 6931
# Average degree: 62
# Average clustering coefficient: 0.89616
# Density: 0.28
# Diameter:  8
# Average shortest path length: 2.98

# %% [markdown]
# Visualizising the similarity network

# %%
nx.draw_spring(G, node_size=1.3, width=0.15)
plt.show()

# %% [markdown]
# Computing degree centrality, betweenness centrality, closeness centrality and eigenvector centrality

# %%
dc = nx.degree_centrality(G)
bc = nx.betweenness_centrality(G)
cc = nx.closeness_centrality(G)
ec = nx.eigenvector_centrality(G)

print(dc)
print(bc)
print(cc)
print(ec)
# Out:
 1.9213033830467115e-05, 'lampaankääpä': 0.1006866569662309, 'lampaanpaisti': 0.00012054082564946944, 'lanttu': 0.10048626204165978, 'latva-artisokka': 0.09977028896706544, 'lehtikaali': 0.1003521330570556, 'lehtikaalisipsit': 0.0017292271914964017, 'leivinjauhe': 8.583895524765803e-05, 'lihakukko': 1.957262272740256e-06, 'liivate': 4.7710258264072816e-05, 'linssikeitto': 0.09978408864059263, 'lipeäkala': 0.00051631182556595, 'lohifilee': 0.0001102197710869908, 'lohkoperuna': 0.007606279178524438, 'maa-artisokka': 0.10068665696623091, 'maapähkinäöljy': 2.4892441307008985e-08, 'made': 0.0005108667960089401, 'maissiöljy': 2.4892441307008985e-08, 'makkarakeitto': 0.10068665696623091, 'maksapaisti': 0.00010498653259543404, 'maltodekstriini': 1.9213033830467115e-05, 'mangoldi': 0.10068665696623091, 'mansikka': 0.1007048855653796, 'manteli': 1.6212169968198158e-07, 'marenki': 1.9189082393698024e-05, 'marja-aronia': 0.10106810613164995, 'meetvursti': 8.130283435785555e-06, 'metsälintu': 0.00014943654012706492, 'minestronekeitto': 0.10010481287624073, 'munakoiso': 0.10068665696623091, 'munatoti': 0.10035213305705562, 'munavoi': 3.758928653799528e-08, 'munuainen': 0.0005152033452395752, 'mustaherukka': 0.1007048855653796, 'mustajuuri': 0.09984733354695108, 'mustapippuri': 7.765950635833882e-06, 'mustekala' ...

# %% [markdown]
# Identifying most influential food items

# %%
top_20_dc = sorted(dc.items(), key=lambda x: x[1], reverse=True)[:20]
top_20_bc = sorted(bc.items(), key=lambda x: x[1], reverse=True)[:20]
top_20_cc = sorted(cc.items(), key=lambda x: x[1], reverse=True)[:20]
top_20_ec = sorted(ec.items(), key=lambda x: x[1], reverse=True)[:20]

print("TOP 20 FOODS\n")
print(f"Highest degree centrality foods: {top_20_dc}\n")
print(f"Highest betweennes centrality foods: {top_20_bc}\n")
print(f"Highest closeness centrsality foods: {top_20_cc}\n")
print(f"Highest eigenvector centrlity foods: {top_20_ec}\n\n")

dc_names, dc_values = zip(*top_20_dc)   
bc_names, bc_values = zip(*top_20_bc)
cc_names, cc_values = zip(*top_20_cc)
ec_names, ec_values = zip(*top_20_ec)

print("TOP 3 FOODS FROM EACH MEASURE CATEGORY\n")
print(f"Top 3 foods with highest degree centrality: {dc_names[:3]}\n")
print(f"Top 3 foods with highest betweennes centrality: {bc_names[:3]}\n")
print(f"Top 3 foods with highest closeness centrality: {cc_names[:3]}\n")
print(f"Top 3 foods with highest eigenvector centrality: {ec_names[:3]}")
# Out:
# TOP 20 FOODS
#
# Highest degree centrality foods: [('punaherukka', 0.45945945945945943), ('ananassalsa', 0.45495495495495497), ('etikkapunajuuri', 0.45495495495495497), ('guava', 0.45495495495495497), ('hapankaali', 0.45495495495495497), ('hillosipulisäilyke', 0.45495495495495497), ('juolukka', 0.45495495495495497), ('karpalo', 0.45495495495495497), ('karviainen', 0.45495495495495497), ('kinkkupasta', 0.45495495495495497), ('lehtikaali', 0.45495495495495497), ('mansikka', 0.45495495495495497), ('marja-aronia', 0.45495495495495497), ('munatoti', 0.45495495495495497), ('mustaherukka', 0.45495495495495497), ('mustajuuri', 0.45495495495495497), ('osteri', 0.45495495495495497), ('palsternakka', 0.45495495495495497), ('pinaatti', 0.45495495495495497), ('piparjuuri', 0.45495495495495497)]
#
# Highest betweennes centrality foods: [('rahkajuoma', 0.10620504081550924), ('porokeitto', 0.1024557797514979), ('silakkahyytelö', 0.1024557797514979), ('sianlapa', 0.08684862172319742), ('lihakukko', 0.06937782168156469), ('mämmi', 0.061714749519324485), ('siankylki', 0.060898098927503024), ('omenahillo', 0.053570279079141386), ('vesikastanja', 0.053201311133905096), ('puolukkahillo', 0.05000589945841477), ('vehnänalkio', 0.04905575163517164), ('katkarapu', 0.0470883966984805), ('rapu', 0.0470883966984805), ('lohkoperuna', 0.046630042204184166), ('rahkavoitaikina', 0.03812380830255229), ('ketsuppi', 0.03793089258706008), ('kastanja', 0.032608230289565665), ('appelsiinimarmeladi', 0.029477635116120122), ('meetvursti', 0.029283769323918137), ('maksapaisti', 0.027876269925774525)]
#
# Highest closeness centrsality foods: [('rahkajuoma', 0.43023255813953487), ('piparjuuri', 0.4228571428571429), ('lehtikaali', 0.41965973534971646), ('munatoti', 0.41965973534971646), ('osteri', 0.41965973534971646), ('pinaatti', 0.41965973534971646), ('ruohosipuli', 0.41965973534971646), ('suppilovahvero', 0.41965973534971646), ('herkkusieni', 0.4180790960451977), ('herkkutatti', 0.4180790960451977), ('kangasrousku', 0.4180790960451977), ('latva-artisokka', 0.4180790960451977), ('ruusukaali', 0.4180790960451977), ('kuusenkerkkä', 0.41729323308270677), ('broilerikeitto', 0.4165103189493433), ('herneenverso', 0.4165103189493433), ('ternimaito', 0.4165103189493433), ('italianpata', 0.4134078212290503), ('nokkonen', 0.41187384044526903), ('punaherukka', 0.4065934065934066)]
#
# Highest eigenvector centrlity foods: [('punaherukka', 0.10128672965536978), ('hapankaali', 0.10106810613164996), ('juolukka', 0.10106810613164996), ('karpalo', 0.10106810613164996), ('karviainen', 0.10106810613164996), ('vadelma', 0.10106810613164996), ('variksenmarja', 0.10106810613164996), ('marja-aronia', 0.10106810613164995), ('porkkana', 0.10106810613164995), ('porkkanamuhennos', 0.10106810613164995), ('raparperi', 0.10106810613164995), ('ruusunmarja', 0.10106810613164995), ('virvoitusjuoma', 0.10070488556537961), ('ananassalsa', 0.1007048855653796), ('etikkapunajuuri', 0.1007048855653796), ('guava', 0.1007048855653796), ('hillosipulisäilyke', 0.1007048855653796), ('mansikka', 0.1007048855653796), ('mustaherukka', 0.1007048855653796), ('palsternakka', 0.1007048855653796)]
#
#
# TOP 3 FOODS FROM EACH MEASURE CATEGORY
#
# Top 3 foods with highest degree centrality: ('punaherukka', 'ananassalsa', 'etikkapunajuuri')
#
# Top 3 foods with highest betweennes centrality: ('rahkajuoma', 'porokeitto', 'silakkahyytelö')
#
# Top 3 foods with highest closeness centrality: ('rahkajuoma', 'piparjuuri', 'lehtikaali')
#
# Top 3 foods with highest eigenvector centrality: ('punaherukka', 'hapankaali', 'juolukka')
